# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
filet = '../yelp_dataset/yelp_academic_dataset_checkin.csv'
dft = pd.read_csv(filet, encoding = 'utf-8')

# %%
dft.head()
# Out:
#    time.Mon-9  time.Fri-16  time.Sat-16  time.Mon-5  time.Thu-13  time.Tue-10  \
# 0         NaN          1.0          2.0         NaN          1.0          2.0
# 1         NaN          NaN          1.0         NaN          1.0          NaN
# 2         NaN          NaN          1.0         NaN          NaN          NaN
# 3         NaN          NaN          NaN         NaN          NaN          NaN
# 4         NaN          NaN          NaN         NaN          NaN          NaN
#
#    time.Thu-15  time.Wed-12  time.Sun-4  time.Sat-17     ...       \
# 0          2.0          NaN         NaN          4.0     ...
# 1          NaN          NaN         NaN          NaN     ...
# 2          NaN          NaN         NaN          NaN     ...
# 3          NaN          NaN         NaN          NaN     ...
# 4          NaN          NaN         NaN          NaN     ...
#
#    time.Fri-19  time.Thu-17  time.Mon-13  time.Thu-8  time.Sat-9  time.Sat-12  \
# 0          3.0          NaN          NaN         NaN         NaN          1.0
# 1          NaN          NaN          1.0         NaN         NaN          NaN
# 2          NaN          NaN          NaN         NaN         NaN          NaN
# 3          NaN          NaN          NaN         NaN         NaN          NaN
# 4          NaN          NaN          NaN         NaN         NaN          NaN
#
#    time.Mon-22  time.Mon-12  time.Sun-20  time.Sun-13
# 0          NaN          1.0          5.0          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          1.0          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 169 columns]

# %%
dft.columns
# Out:
# Index(['time.Mon-9', 'time.Fri-16', 'time.Sat-16', 'time.Mon-5', 'time.Thu-13',
#        'time.Tue-10', 'time.Thu-15', 'time.Wed-12', 'time.Sun-4',
#        'time.Sat-17',
#        ...
#        'time.Fri-19', 'time.Thu-17', 'time.Mon-13', 'time.Thu-8', 'time.Sat-9',
#        'time.Sat-12', 'time.Mon-22', 'time.Mon-12', 'time.Sun-20',
#        'time.Sun-13'],
#       dtype='object', length=169)

# %%
dft.shape
# Out:
# (157075, 169)

# %%
sns.heatmap(dft.corr())

# %%
df['Total_checkin']= dft.iloc[:, :].sum(axis=1)

# %%
df['Total_checkin']
# Out:
# 0         151.0
# 1           7.0
# 2           6.0
# 3           3.0
# 4           5.0
# 5           2.0
# 6          29.0
# 7          29.0
# 8          47.0
# 9           2.0
# 10          3.0
# 11         24.0
# 12         43.0
# 13         56.0
# 14          1.0
# 15          1.0
# 16          8.0
# 17         22.0
# 18        103.0
# 19          2.0
# 20         12.0
# 21         42.0
# 22          6.0
# 23         15.0
# 24         12.0
# 25          8.0
# 26          3.0
# 27          4.0
# 28        131.0
# 29         25.0
#           ...
# 157045     19.0
# 157046     25.0
# 157047      2.0
# 157048      1.0
# 157049      3.0
# 157050      8.0
# 157051      2.0
# 157052     14.0
# 157053      4.0
# 157054      2.0
# 157055     28.0
# 157056     10.0
# 157057      4.0
# 157058      1.0
# 157059      9.0
# 157060      3.0
# 157061      4.0
# 157062      5.0
# 157063     20.0
# 157064      1.0
# 157065      1.0
# 157066      5.0
# 157067     27.0
# 157068     23.0
# 157069      4.0
# 157070      2.0
# 157071     14.0
# 157072      2.0
# 157073      3.0
# 157074      2.0
# Name: Total_checkin, Length: 157075, dtype: float64
